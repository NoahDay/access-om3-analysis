# %%
from access_nri_intake.source import builders
from dask.distributed import Client
# Hide some warnings
logging.basicConfig(level=logging.WARNING)

# %%
import intake

esm_datastore = intake.open_esm_datastore(
    "/g/data/ps29/nd0349/runs/access-om3/archive/mom6-cice6_ryf_rel/intake_esm_ds.json", 
    columns_with_iterables=[
            "variable",
            "variable_long_name",
            "variable_standard_name",
            "variable_cell_methods",
            "variable_units",
    ] # This is important
)

esm_datastore
# Out:
# <p><strong>intake_esm_ds catalog with 6 dataset(s) from 3050 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>filename</th>
#       <td>3001</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>3050</td>
#     </tr>
#     <tr>
#       <th>filename_timestamp</th>
#       <td>1200</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>601</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>601</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>185</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
client = Client(threads_per_worker = 1)
client
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44979 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:39181' processes=28 threads=28, memory=125.19 GiB>
# 2025-03-26 12:53:27,603 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,608 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,612 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,627 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,637 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,642 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,716 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,726 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,739 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,747 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,756 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,765 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,772 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,789 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,800 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,809 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,822 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,829 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,838 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,846 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,856 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,863 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,881 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,893 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:53:27,901 - distributed.nanny - WARNING - Restarting worker
# 2025-03-26 12:54:52,684 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-ba08201098e98f9d7315a53d718129ff' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544b7768d80>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544d067dac0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('ac05dd530892eaaa', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('b054b7e3d6f522f5', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:55,053 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-89112946f36d3b1ef1ba98947fdf1e23' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544e0fba340>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544e0f55540>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('e1a0b4c134124db0', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('fae1020b5b3d8b88', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:55,248 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-6af765ff814123c0073265b903f1de20' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544cc52f3c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544cf770a00>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('4243d116e0c2ab97', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('32d12112a8bded18', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:55,553 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-a6a96a6f75aac25513b4601c9a58f138' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544cf2ddb40>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544f0166880>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('4bb13e90cd20a433', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('7f0cf7746584883d', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:55,748 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-d83166b20f8f41a2a565182a525eddf6' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x154548a193c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544d893da40>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('8d3f8c5cf15e9f30', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('7c576242477c849a', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:56,065 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-29907d5e3c59a6296a9dbcb4a90c8da0' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544b77b9040>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544d1477c40>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('a42b0a2bbcbfe002', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('8ef41ee125390d85', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:56,240 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-7c4c5958b9569a10a830b7e70f322059' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x154548983000>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x154502a773c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d90b13961af74103', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('75d8361c0642cee4', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:56,567 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-5eae13d5f0856891c6cd0206267e430e' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x154548919980>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544e2a24ec0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('4ed9e8dd8846298d', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('780fa1dff475944f', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:56,773 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-3ba5b6c6a90df82cc4adc7c45e03649d' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1547d79b3080>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544cfa195c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('682bb995a462911c', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('fa301aa3ee35c6ee', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:57,051 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-7e357eb0e851cf1a05ee504a3d3e0b64' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1545022f2700>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544c9678a80>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('440c8a52ff072c7a', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('43a7ae666be0c692', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:57,248 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-4fe5082876ab09f53b6dfa85c1b8bc33' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544d645aac0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544f0563f80>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('cf8491b992df23c4', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('bc41487aeca43ae6', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:57,592 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-3a32dd7e47df152d386810245e350cf7' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544d8f9d5c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544e1bca680>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('4c84378e1471fbad', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('54160f57d32e643c', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:57,752 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-298ab77c3a4552dd8718504a0d943381' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544d64e8400>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544e258ef00>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('3db703ec1dd89738', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('54310ea39901dd5b', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:58,053 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-4876efbf316661a4d33b66b3f056a01a' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544f036b680>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544bad62680>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('0091225df2d01699', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2402c961934af8f5', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:58,221 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-931955067f3df728cc05941a8d4b1af4' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544cf274180>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544cbba8b00>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d5e7e508a7e9b6f3', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('106af0f41c7d3e0a', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:58,532 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-01c7aa33f1ee65a7d14bda31a16994b1' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544db9e57c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x15454897ac00>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d0a18e7b553da76d', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('60869ad210ce72d1', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:58,765 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-402a522c34712e248121270db8ad8589' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544bc346d40>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544bc864fc0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('a9bed63bf5bcc0a5', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('82b4fe01253ebc1f', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:59,031 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-1ffcd04ffe79f9ee6ea86821541c2907' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544bfff9f40>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1547deb3dfc0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('8f60508c52ab745d', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('6522a361548c91b7', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:59,244 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-186a630a197b37edc8400948e649165e' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544be312080>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544f007c180>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('cf4c0a4abb22e0f6', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('8f0f92ebd3d35d07', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:59,534 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-34943fe0c84ea378ca300339210d2b00' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544f2a49400>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544e2b58180>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d028290f47e3b13a', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('0a69dd46f9361279', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:54:59,728 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-14b06b6141910853b0e19e0d73f53e32' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1547dd2c99c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544e8c02f00>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('6c62150d77e026b3', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('466ecfcaa67f095e', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:00,049 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-91f6b0e962c43207a8e1e320c0d15ea1' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544b9a3c080>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544ca871a40>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d35fa2adb60d5d2c', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('d586032c852ded9b', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:00,225 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-a28417c5fdad131dbc4350e8e3045a11' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1545092991c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544d219f4c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('a57970bfed691e74', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('77e9d47dab8a9098', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:00,569 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-018cdde52d237da007d2a246fed317d4' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544b9b47740>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544b8d45140>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('532df98672910442', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('cfdba900967fc441', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:01,018 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-e0a632e6f41e664847843ad3b1cb7448' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544cd01afc0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544d6370280>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('73847987dbe8f4f9', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('94d4bb8ede03fe5c', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:01,107 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-903bf1a0a8b93eb9c8651560bc59e42e' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544e6a002c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1545090f47c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('1f7afc8bdb86af53', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('1e5d618d2971a044', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:01,250 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-1722efe9613370d3d0a9bf243ee10c81' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1547dcf95cc0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544bcd74400>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('40c140d1ea877baf', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('f7b256f5511c46c8', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:01,589 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-217bd92525253d81faca24df2a53bcb5' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544ee9ef5c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544bcd995c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('13439bcdb1e3c93b', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('72deaded87564e3c', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:01,781 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-eb3bc6d9c01eb1d0eaf7606cfb369c16' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544f2e298c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544efd3d140>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('8517e78859052480', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('b3cfbff345d50bf0', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:02,011 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-b53888e040de5fa498c06ea0957c5a70' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544be733440>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544eebb9200>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('13baef2aa62dd4b2', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('c26c62c51370226e', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:02,088 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-cfaf0987999fbb34de6e357863d6fae6' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544b804f6c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544ed72cf80>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('9b424cf3d22a6db6', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('392791395e393f2b', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:02,535 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-9b5550a04c33b799b272107e7cbcfc54' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544da395440>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544ccdb0540>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('842b2aa5d0069452', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('fe5c685e09aa1e69', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:02,735 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-8606cd99bd30ae69298bd9e2886283dc' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544da2f1a00>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x154500e55640>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('3285deec94cac56a', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('c417deefefcd0a4d', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:55:03,031 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-36e27e4e436d23d939bc5237d4669b6e' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# ...
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a383dbc0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a3828680>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('57db8268875437bb', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2f5cbdc7de4e8856', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:58:51,089 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-048e3b7bfc754f4e9af7dfb20cb0e33e' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a39b7f80>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a383f7c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('fcc05c245d51582e', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2927db83c6add3d5', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:58:51,254 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-e4a6770bd575e506304b6753eb6bdcb9' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a38100c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a3828c40>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('82c359206d670626', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('cfeaff85108267c5', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:58:51,520 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-3f567c08bd0e722e67a0257ae9f3ea4c' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a38fb8c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a370ad80>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('39cc650a16b6f143', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2423e41322addf2d', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:58:51,574 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-d2ab17385ff5a83a5165b0ecc1ebb4fd' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a38fb880>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a38fa7c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('8d0d9d8a366bee9a', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('5de9bdfa52dceede', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:58:51,733 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-159b3bfafca5b63ff7d6b25f9e5fdc0a' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a6119200>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a370bc40>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('7835aace772dbad8', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('5564b3d3468e2c0e', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:58:52,066 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-393668ab244a643a97a8e7218c7f122d' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a388ec80>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a373a700>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('b6e34f8737fc5617', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('01198163da45489e', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:58:52,243 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-103dec61ceff50489a498691205c10af' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a3740380>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a3741740>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('5902013f18e69389', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('6b05bd9ad1306f81', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:58:52,519 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-0a0014d91fe04d080d0a283041e8b893' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a3776480>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a37512c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('2cf194289a14b30c', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('65b3fc225e6ebf74', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:58:52,593 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-91651cc6599bdd6e638b8ed7fa6b9489' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a3753780>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a37520c0>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('c25b014b4aa2057a', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('90f762eec70776d1', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:58:52,767 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-760a7c961e5a4b490034bb231bf0e54a' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a3752680>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1544a39d7340>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('6e29d976af3989d3', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('60b83c574ac31ef7', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2025-03-26 12:58:53,244 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-NCAT-c4dd61f57c4d2b4dcf7f9c6b5665509c' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: processing
# old run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1545020a6140>, key=BasicIndexer((slice(None, None, None),))))),), {})
# new run_spec: (<function execute_task at 0x154ac9107b50>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1545488cc600>, key=BasicIndexer((slice(None, None, None),))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('ecbbf9350b9ad48f', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('48e4b7c62a00ac18', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()

# %% [markdown]
# ## Search for unique attributes

# %%
esm_datastore.unique().frequency
esm_datastore.search(frequency='1mon').unique().variable
# esm_datastore.unique().variable
# Out:
# ['time',
#  'time_bounds',
#  'NCAT',
#  'VGRDi',
#  'VGRDs',
#  'VGRDb',
#  'VGRDa',
#  'blkmask',
#  'ANGLE',
#  'ANGLET',
#  'hi_m',
#  'hs_m',
#  'Tsfc_m',
#  'aice_m',
#  'uvel_m',
#  'vvel_m',
#  'uatm_m',
#  'vatm_m',
#  'sice_m',
#  'fswup_m',
#  'fswdn_m',
#  'flwdn_m',
#  'snow_ai_m',
#  'rain_ai_m',
#  'frzmlt_m',
#  'scale_factor_m',
#  'fswabs_ai_m',
#  'albsni_m',
#  'alvdr_ai_m',
#  'alidr_ai_m',
#  'alvdf_ai_m',
#  'alidf_ai_m',
#  'albice_m',
#  'albsno_m',
#  'flat_ai_m',
#  'fsens_ai_m',
#  'flwup_ai_m',
#  'evap_ai_m',
#  'Tair_m',
#  'congel_m',
#  'frazil_m',
#  'snoice_m',
#  'meltt_m',
#  'melts_m',
#  'meltb_m',
#  'meltl_m',
#  'fresh_ai_m',
#  'fsalt_m',
#  'fsalt_ai_m',
#  'fhocn_ai_m',
#  'fswthru_ai_m',
#  'strairx_m',
#  'strairy_m',
#  'strtltx_m',
#  'strtlty_m',
#  'strcorx_m',
#  'strcory_m',
#  'strocnx_m',
#  'strocny_m',
#  'strintx_m',
#  'strinty_m',
#  'strength_m',
#  'divu_m',
#  'shear_m',
#  'vort_m',
#  'dvidtt_m',
#  'dvidtd_m',
#  'daidtt_m',
#  'daidtd_m',
#  'trsig_m',
#  'ice_present_m',
#  'fcondtop_ai_m',
#  'fmeltt_ai_m',
#  'sifb_m',
#  'opening_m',
#  'aicen_m',
#  'vicen_m',
#  'fsurfn_ai_m',
#  'fcondtopn_ai_m',
#  'fmelttn_ai_m',
#  'flatn_ai_m',
#  'fsensn_ai_m',
#  'scalar_axis',
#  'nv',
#  'xq',
#  'yh',
#  'zl',
#  'xh',
#  'yq',
#  'zi',
#  'soga',
#  'thetaoga',
#  'uh',
#  'vh',
#  'vhbt',
#  'uhbt',
#  'agessc',
#  'T_ady_2d',
#  'T_adx_2d',
#  'T_diffy_2d',
#  'T_diffx_2d',
#  'diftrelo',
#  'diftrblo',
#  'difmxybo',
#  'difmxylo',
#  'volcello',
#  'vmo',
#  'vhGM',
#  'vhml',
#  'umo',
#  'uhGM',
#  'uhml',
#  'uo',
#  'vo',
#  'h',
#  'e',
#  'thetao',
#  'so',
#  'KE',
#  'rhopot0',
#  'oml',
#  'tauuo',
#  'tauvo',
#  'friver',
#  'prsn',
#  'prlq',
#  'evs',
#  'hfsso',
#  'rlntds',
#  'hfsnthermds',
#  'sfdsi',
#  'rsntds',
#  'hfds',
#  'ustar',
#  'hfsifrazil',
#  'wfo',
#  'vprec',
#  'ficeberg',
#  'fsitherm',
#  'hflso',
#  'pso',
#  'seaice_melt_heat',
#  'Heat_PmE',
#  'salt_flux_added',
#  'heat_content_lrunoff',
#  'heat_content_frunoff',
#  'heat_content_lprec',
#  'heat_content_fprec',
#  'heat_content_vprec',
#  'heat_content_cond',
#  'heat_content_evap',
#  'SSH',
#  'tos',
#  'sos',
#  'SSU',
#  'SSV',
#  'mass_wt',
#  'opottempmint',
#  'somint',
#  'Rd_dx',
#  'speed',
#  'mlotst',
#  'average_T1',
#  'average_T2',
#  'average_DT',
#  'time_bnds',
#  'z_l',
#  'z_i']

# %%
# %%time
# esm_datastore.search(frequency='1mon',variable='aice_m').to_dataset_dict()

# ds = esm_datastore.search(variable="aice_m").search(frequency="1mon").to_dask()
esm_datastore_filtered = esm_datastore.search(
    variable=["aice_m"], frequency="1mon", require_all_on="path"
)
# Out:
# CPU times: user 5.04 s, sys: 741 ms, total: 5.78 s
# Wall time: 4.93 s

# %%
xarray_open_kwargs = {"chunks": {"time": -1, "xt_ocean": -1, "yt_ocean": -1}}

ds = esm_datastore_filtered.to_dask(xarray_open_kwargs=xarray_open_kwargs)

# %%
ds["aice_m"]
# Out:
# <xarray.DataArray 'aice_m' (time: 600, nj: 300, ni: 360)> Size: 518MB
# dask.array<concatenate, shape=(600, 300, 360), dtype=float64, chunksize=(1, 150, 180), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 5kB 1900-01-16 12:00:00 ... 1949-12-16 12:00:00
# Dimensions without coordinates: nj, ni
# Attributes:
#     units:          1
#     long_name:      ice area  (aggregate)
#     cell_measures:  area: tarea
#     cell_methods:   time: mean
#     time_rep:       averaged

# %%
catalog_filtered_example = catalog.search(model="ACCESS-OM2")
catalog_filtered_example

# %%
# Flatten the lists in the 'variable' column and then get unique values
import itertools

# Flatten the lists and get unique variable names
unique_variables = set(itertools.chain(*esm_datastore.df['variable']))
print(unique_variables)
# Out:
# {'ULON', 'dissicos_raw', 'bih_fric_v', 'frazil_3d_int_z', 'runoff', 'lw_heat', 'usurf', 'trsig_m', 'diff_cbt_t', 'blkmask', 'divu_m', 'fprec_melt_heat', 'total_ocean_evap_heat', 'sfc_hflux_from_water_evap', 'strcorx_m', 'temp_advection', 'temp_xflux_adv', 'fgco2_raw', 'u', 'total_ocean_lprec', 'tarea', 'salt', 'snow_ai_m', 'salt_vdiffuse_sbc', 'neutral_diffusion_temp', 'pot_rho_2', 'vsurf', 'rho_dzt', 'total_ocean_fprec', 'pco2', 'average_T2', 'sea_level', 'fswdn_m', 'surface_dic', 'flwdn_m', 'tx_trans_rho_gm', 'o2os_raw', 'meltl_m', 'melts_m', 'fmelttn_ai_m', 'albsno_m', 'pot_temp', 'total_ocean_pme_river', 'mixdownslope_salt', 'tx_trans_nrho_submeso', 'geolat_t', 'average_DT', 'eta_global', 'gm_eddy_ke_source', 'salt_int_rhodz', 'snoice_m', 'hu', 'frazil', 'albsni_m', 'wfimelt', 'surface_pot_temp_max', 'temp_yflux_sigma', 'dyu', 'vvel_m', 'alidf_ai_m', 'caco3', 'bottom_temp_max', 'dvidtt', 'aice', 'eta_nonbouss', 'temp_vdiffuse_diff_cbt_conv', 'sice_m', 'fmeltt_ai_m', 'bmf_u', 'eta_t', 'dvidtd', 'salt_vdiffuse_diff_cbt', 'intpp_raw', 'pe_tot', 'hs_m', 'fswfac_m', 'uvel_m', 'tau_y', 'area_u', 'temp_xflux_gm_int_z', 'average_T1', 'vatm_m', 'bottom_temp', 'talkos_raw', 'total_ocean_swflx', 'total_volume_seawater', 'TLON', 'evap_ai_m', 'total_ocean_sfc_salt_flux_coupler', 'drag_coeff', 'area_t', 'pme_river', 'fsalt_m', 'ekman_we', 'neutral_diffusion_salt', 'temp_submeso', 'dvidtd_m', 'patm_t', 'eta_adjust', 'total_ocean_hflux_prec', 'total_ocean_swflx_vis', 'albice_m', 'strintx_m', 'frzmlt', 'mh_flux', 'v', 'rho', 'sfc_hflux_from_runoff', 'sss_sq', 'usq', 'sss', 'phy', 'salt_global_ave', 'tau_x', 'bmf_v', 'ty_trans', 'kmt', 'pme_net', 'total_ocean_evap', 'dvidtt_m', 'phyos_raw', 'geolat_c', 'fsens_ai_m', 'temp_rhodzt', 'ice_present_m', 'daidtd_m', 'swflx', 'uvel', 'strocny_m', 'temp_nonlocal_KPP', 'salt_vdiffuse_k33', 'temp_global_ave', 'surface_pot_temp_min', 'temp_yflux_adv_int_z', 'geolon_t', 'total_mass_seawater', 'opening_m', 'tmask', 'sens_heat', 'surface_fe', 'hblt_max', 'age_global', 'neutral_gm_salt', 'sfc_hflux_pme', 'temp', 'diff_cbt_s', 'temp_yflux_submeso_int_z', 'vert_pv', 'pot_rho_0', 'ULAT', 'frazil_m', 'fgco2nat_raw', 'salt_rhodzt', 'alvdr_ai_m', 'pbot_t', 'fprec', 'alidr_ai_m', 'TLAT', 'HTN', 'ty_trans_rho', 'salt_nonlocal_KPP', 'fswthru_ai_m', 'temp_xflux_adv_int_z', 'fhocn_ai_m', 'surface_det', 'evap', 'salt_tendency', 'hi', 'aiso_bih', 'vsq', 'neutral_gm_temp', 'zoo', 'total_ocean_lw_heat', 'salt_submeso', 'total_ocean_river', 'net_sfc_heating', 'congel_m', 'strairx_m', 'shear_m', 'total_ocean_melt', 'tx_trans', 'salt_eta_smooth', 'sfc_salt_flux_restore', 'total_ocean_sens_heat', 'frzmlt_m', 'total_ocean_hflux_evap', 'strtltx_m', 'dxu', 'salt_vdiffuse_diff_cbt_conv', 'lprec', 'total_ocean_hflux_coupler', 'rhoave', 'temp_int_rhodz', 'kmu', 'no3os_raw', 'strtlty_m', 'ht', 'liceht', 'fcondtopn_ai_m', 'NCAT', 'fsalt_ai_m', 'fresh_ai_m', 'total_ocean_mh_flux', 'daidtt_m', 'alvdf_ai_m', 'temp_sigma_diff', 'bih_fric_u', 'flatn_ai_m', 'sfc_salt_flux_ice', 'adic', 'sfc_salt_flux_coupler', 'temp_yflux_gm_int_z', 'tx_trans_gm', 'temp_tendency', 'temp_eta_smooth', 'ANGLE', 'surface_zoo', 'buoyfreq2_wt', 'congel', 'tz_trans', 'tx_trans_int_z', 'vicen_m', 'stf09', 'mld', 'dht', 'psiu', 'mld_min', 'fswabs_ai_m', 'frazil_3d', 'strength_m', 'mixdownslope_temp', 'fcondtop_ai_m', 'temp_yflux_adv', 'tx_trans_rho', 'temp_yflux_ndiffuse_int_z', 'rain_ai_m', 'wfiform', 'temp_xflux_sigma', 'sst_sq', 'paco2', 'melt', 'total_ocean_river_heat', 'sfc_salt_flux_runoff', 'vvel', 'meltb_m', 'salt_rivermix', 'o2', 'temp_vdiffuse_diff_cbt', 'ty_trans_rho_gm', 'temp_xflux_ndiffuse_int_z', 'flat_ai_m', 'uarea', 'HTE', 'horz_bih_diss', 'det', 'tx_trans_submeso', 'strcory_m', 'sfc_hflux_coupler', 'strinty_m', 'fgo2_raw', 'fswup_m', 'salt_surface_ave', 'total_ocean_runoff_heat', 'temp_rivermix', 'aice_m', 'agm', 'total_ocean_salt', 'total_ocean_heat', 'temp_xflux_submeso_int_z', 'salt_advection', 'dyt', 'alk', 'total_ocean_runoff', 'evap_heat',  ...

# %%
# %%time
# ds = esm_datastore.search(variable="aice_m").search(frequency="1mon").to_dask().aice_m
# esm_datastore_filtered.unique().variable
esm_datastore_filtered

# %%
ds = esm_datastore.search(variable="alvdf_ai", frequency="1mon").to_dask()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ds = esm_datastore.search(variable="alvdf_ai", frequency="1mon").to_dask()
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/intake_esm/core.py:811, in esm_datastore.to_dask(self, **kwargs)
#     796 """
#     797 Convert result to an xarray dataset.
#     798
#    (...)
#     808 :py:class:`~xarray.Dataset`
#     809 """
#     810 if len(self) != 1:  # quick check to fail more quickly if there are many results
# --> 811     raise ValueError(
#     812         f'Expected exactly one dataset. Received {len(self)} datasets. Please refine your search or use `.to_dataset_dict()`.'
#     813     )
#     814 res = self.to_dataset_dict(**{**kwargs, 'progressbar': False})
#     815 if len(res) != 1:  # extra check in case kwargs did modify something
#
# ValueError: Expected exactly one dataset. Received 0 datasets. Please refine your search or use `.to_dataset_dict()`.

# %%
esm_datastore
# Out:
# <p><strong>mydatastore catalog with 11 dataset(s) from 2013 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>path</th>
#       <td>2013</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>319</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>855</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>855</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>131</td>
#     </tr>
#     <tr>
#       <th>filename</th>
#       <td>1473</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ds["temp"].isel(time=-1, st_ocean=0).plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ds["temp"].isel(time=-1, st_ocean=0).plot()
#
# NameError: name 'ds' is not defined
